# %% [markdown]
# # Explorando os dados

# %%
import pandas as pd

# %%
df = pd.read_csv('Comparativo_Geração_de_Energia_Semana_Full_Data_data (1).csv', sep=';')

# %%
df.head()
# Out:
#   Data Escala de Tempo 1 GE Comp 3 Selecione Comparar GE Comp 3 dsc_estado  \
# 0              01/01/2015 00:00:00                      Térmica   AMAZONAS
# 1              01/01/2018 00:00:00                      Térmica   AMAZONAS
# 2              01/01/2016 00:00:00                      Térmica   AMAZONAS
# 3              01/01/2017 00:00:00                      Térmica   AMAZONAS
# 4              01/01/2019 00:00:00                      Térmica   AMAZONAS
#
#   id_subsistema Modalidade de Operação nom_tipocombustivel2 nom_tipousinasite  \
# 0         Norte               Tipo III             Petróleo           Térmica
# 1         Norte               Tipo III             Petróleo           Térmica
# 2         Norte               Tipo III             Petróleo           Térmica
# 3         Norte               Tipo III             Petróleo           Térmica
# 4         Norte               Tipo III             Petróleo           Térmica
#
#      nom_usina2 Período Verifica GE Comp 3  \
# 0   Itacoatiara                 Verdadeiro
# 1   Itacoatiara                 Verdadeiro
# 2   Itacoatiara                 Verdadeiro
# 3   Itacoatiara                 Verdadeiro
# 4   Itacoatiara                 Verdadeiro
#
#                                     USINACEG  ... Data Dica Comp  \
# 0   Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2015
# 1   Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2018
# 2   Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2016
# 3   Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2017
# 4   Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2019
#
#    Data do Incio da Semana Din Instante GE Comp 3         Din Instante  \
# 0                                             NaN  31/12/2015 00:00:00
# 1                                             NaN  31/12/2018 00:00:00
# 2                                             NaN  31/12/2016 00:00:00
# 3                                             NaN  31/12/2017 00:00:00
# 4                                             NaN  31/12/2019 00:00:00
#
#    Din Instante GE Comp 3 Período Data 1 GE Comp 3  Período Exibido GE  \
# 0     01/01/2015 00:00:00      01/01/2015 00:00:00                   1
# 1     01/01/2018 00:00:00      01/01/2018 00:00:00                   1
# 2     01/01/2016 00:00:00      01/01/2016 00:00:00                   1
# 3     01/01/2017 00:00:00      01/01/2017 00:00:00                   1
# 4     01/01/2019 00:00:00      01/01/2019 00:00:00                   1
#
#             Table Name  Texto Incio Semana Val Geraenergiacongwh  \
# 0  gr_anusinaprevcarga                 NaN                     0
# 1  gr_anusinaprevcarga                 NaN                     0
# 2  gr_anusinaprevcarga                 NaN            0,29023624
# 3  gr_anusinaprevcarga                 NaN                     0
# 4  gr_anusinaprevcarga                 NaN                     0
#
#   Val Geraenergiaconmwmed
# 0                       0
# 1                       0
# 2                0,033041
# 3                       0
# 4                       0
#
# [5 rows x 31 columns]

# %%
df1 = df[['dsc_estado', 
          'id_subsistema', 
          'nom_tipousinasite', 
          'nom_tipocombustivel2', 
          'nom_usina2', 
          'Data Dica Comp',
          'Val Geraenergiacongwh',
          'Val Geraenergiaconmwmed']]

df1.head()
# Out:
#   dsc_estado id_subsistema nom_tipousinasite nom_tipocombustivel2  \
# 0   AMAZONAS         Norte           Térmica             Petróleo
# 1   AMAZONAS         Norte           Térmica             Petróleo
# 2   AMAZONAS         Norte           Térmica             Petróleo
# 3   AMAZONAS         Norte           Térmica             Petróleo
# 4   AMAZONAS         Norte           Térmica             Petróleo
#
#      nom_usina2  Data Dica Comp Val Geraenergiacongwh Val Geraenergiaconmwmed
# 0   Itacoatiara            2015                     0                       0
# 1   Itacoatiara            2018                     0                       0
# 2   Itacoatiara            2016            0,29023624                0,033041
# 3   Itacoatiara            2017                     0                       0
# 4   Itacoatiara            2019                     0                       0

# %%
df['dsc_estado'].nunique()
# Out:
# 27

# %%
escola = df['dsc_estado'].value_counts()
escola.head()
# Out:
# MINAS GERAIS         2456
# SAO PAULO            2393
# RIO GRANDE DO SUL    1837
# BAHIA                1704
# SANTA CATARINA       1561
# Name: dsc_estado, dtype: int64

# %%
sp = df[df['dsc_estado'] == 'SAO PAULO']
display(sp)
# Out:
#       Data Escala de Tempo 1 GE Comp 3 Selecione Comparar GE Comp 3  \
# 401                01/01/2015 00:00:00                 Hidrelétrica
# 402                01/01/2018 00:00:00                 Hidrelétrica
# 403                01/01/2019 00:00:00                 Hidrelétrica
# 404                01/01/2016 00:00:00                 Hidrelétrica
# 405                01/01/2017 00:00:00                 Hidrelétrica
# ...                                ...                          ...
# 18756              01/01/2019 00:00:00                      Térmica
# 18757              01/01/2016 00:00:00                      Térmica
# 18758              01/01/2017 00:00:00                      Térmica
# 18759              01/01/2020 00:00:00                      Térmica
# 18760              01/01/2021 00:00:00                      Térmica
#
#       dsc_estado         id_subsistema Modalidade de Operação  \
# 401    SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# 402    SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# 403    SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# 404    SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# 405    SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# ...          ...                   ...                    ...
# 18756  SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# 18757  SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# 18758  SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# 18759  SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# 18760  SAO PAULO  Sudeste/Centro-Oeste               Tipo III
#
#       nom_tipocombustivel2 nom_tipousinasite  \
# 401             Hidráulica      Hidrelétrica
# 402             Hidráulica      Hidrelétrica
# 403             Hidráulica      Hidrelétrica
# 404             Hidráulica      Hidrelétrica
# 405             Hidráulica      Hidrelétrica
# ...                    ...               ...
# 18756             Petróleo           Térmica
# 18757             Petróleo           Térmica
# 18758             Petróleo           Térmica
# 18759             Petróleo           Térmica
# 18760             Petróleo           Térmica
#
#                                    nom_usina2 Período Verifica GE Comp 3  \
# 401                        Reynaldo Gonçalves                 Verdadeiro
# 402                        Reynaldo Gonçalves                 Verdadeiro
# 403                        Reynaldo Gonçalves                 Verdadeiro
# 404                        Reynaldo Gonçalves                 Verdadeiro
# 405                        Reynaldo Gonçalves                 Verdadeiro
# ...                                       ...                        ...
# 18756   PETROCOQUE S.A. INDUSTRIA E COMERCIO.                 Verdadeiro
# 18757   PETROCOQUE S.A. INDUSTRIA E COMERCIO.                 Verdadeiro
# 18758   PETROCOQUE S.A. INDUSTRIA E COMERCIO.                 Verdadeiro
# 18759   PETROCOQUE S.A. INDUSTRIA E COMERCIO.                 Verdadeiro
# 18760   PETROCOQUE S.A. INDUSTRIA E COMERCIO.                 Verdadeiro
#
#                                                 USINACEG  ... Data Dica Comp  \
# 401      Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2015
# 402      Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2018
# 403      Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2019
# 404      Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2016
# 405      Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2017
# ...                                                  ...  ...            ...
# 18756   PETROCOQUE S.A. INDUSTRIA E COMERCIO. (CEG: U...  ...           2019
# 18757   PETROCOQUE S.A. INDUSTRIA E COMERCIO. (CEG: U...  ...           2016
# 18758   PETROCOQUE S.A. INDUSTRIA E COMERCIO. (CEG: U...  ...           2017
# 18759   PETROCOQUE S.A. INDUSTRIA E COMERCIO. (CEG: U...  ...           2020
# 18760   PETROCOQUE S.A. INDUSTRIA E COMERCIO. (CEG: U...  ...           2021
#
#        Data do Incio da Semana Din Instante GE Comp 3         Din Instante  \
# 401                                               NaN  31/12/2015 00:00:00
# 402                                               NaN  31/12/2018 00:00:00
# 403                                               NaN  31/12/2019 00:00:00
# 404                                               NaN  31/12/2016 00:00:00
# 405                                               NaN  31/12/2017 00:00:00
# ...                                               ...                  ...
# 18756                                             NaN  31/12/2019 00:00:00
# 18757                                             NaN  31/12/2016 00:00:00
# 18758                                             NaN  31/12/2017 00:00:00
# 18759                                             NaN  31/12/2020 00:00:00
# 18760                                             NaN  31/12/2021 00:00:00
#
#        Din Instante GE Comp 3 Período Data 1 GE Comp 3  Período Exibido GE  \
# 401       01/01/2015 00:00:00      01/01/2015 00:00:00                   1
# 402       01/01/2018 00:00:00      01/01/2018 00:00:00                   1
# 403       01/01/2019 00:00:00      01/01/2019 00:00:00                   1
# 404       01/01/2016 00:00:00      01/01/2016 00:00:00                   1
# 405       01/01/2017 00:00:00      01/01/2017 00:00:00                   1
# ...                       ...                      ...                 ...
# 18756     01/01/2019 00:00:00      01/01/2019 00:00:00                   1
# 18757     01/01/2016 00:00:00      01/01/2016 00:00:00                   1
# 18758     01/01/2017 00:00:00      01/01/2017 00:00:00                   1
# 18759     01/01/2020 00:00:00      01/01/2020 00:00:00                   1
# 18760     01/01/2021 00:00:00      01/01/2021 00:00:00                   1
#
#                 Table Name  Texto Incio Semana Val Geraenergiacongwh  \
# 401    gr_anusinaprevcarga                 NaN                     0
# 402    gr_anusinaprevcarga                 NaN                     0
# 403    gr_anusinaprevcarga                 NaN                     0
# 404    gr_anusinaprevcarga                 NaN                     0
# 405    gr_anusinaprevcarga                 NaN                     0
# ...                    ...                 ...                   ...
# 18756  gr_anusinaprevcarga                 NaN           41,06788628
# 18757  gr_anusinaprevcarga                 NaN           22,01259151
# 18758  gr_anusinaprevcarga                 NaN           51,31376803
# 18759  gr_anusinaprevcarga                 NaN           39,19521639
# 18760  gr_anusinaprevcarga                 NaN           29,59521521
#
#       Val Geraenergiaconmwmed
# 401                         0
# 402                         0
# 403                         0
# 404                         0
# 405                         0
# ...                       ...
# 18756                4,688114
# 18757                2,505987
# 18758                5,857736
# 18759                4,462114
# 18760                6,812894
#
# [2393 rows x 31 columns]

# %%
sp['Val Geraenergiacongwh'] = sp['Val Geraenergiacongwh'].str.replace(',', '.')
sp['Val Geraenergiaconmwmed'] = sp['Val Geraenergiaconmwmed'].str.replace(',', '.')
sp.head()
# Out:
#     Data Escala de Tempo 1 GE Comp 3 Selecione Comparar GE Comp 3 dsc_estado  \
# 401              01/01/2015 00:00:00                 Hidrelétrica  SAO PAULO
# 402              01/01/2018 00:00:00                 Hidrelétrica  SAO PAULO
# 403              01/01/2019 00:00:00                 Hidrelétrica  SAO PAULO
# 404              01/01/2016 00:00:00                 Hidrelétrica  SAO PAULO
# 405              01/01/2017 00:00:00                 Hidrelétrica  SAO PAULO
#
#             id_subsistema Modalidade de Operação nom_tipocombustivel2  \
# 401  Sudeste/Centro-Oeste               Tipo III           Hidráulica
# 402  Sudeste/Centro-Oeste               Tipo III           Hidráulica
# 403  Sudeste/Centro-Oeste               Tipo III           Hidráulica
# 404  Sudeste/Centro-Oeste               Tipo III           Hidráulica
# 405  Sudeste/Centro-Oeste               Tipo III           Hidráulica
#
#     nom_tipousinasite           nom_usina2 Período Verifica GE Comp 3  \
# 401      Hidrelétrica   Reynaldo Gonçalves                 Verdadeiro
# 402      Hidrelétrica   Reynaldo Gonçalves                 Verdadeiro
# 403      Hidrelétrica   Reynaldo Gonçalves                 Verdadeiro
# 404      Hidrelétrica   Reynaldo Gonçalves                 Verdadeiro
# 405      Hidrelétrica   Reynaldo Gonçalves                 Verdadeiro
#
#                                              USINACEG  ... Data Dica Comp  \
# 401   Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2015
# 402   Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2018
# 403   Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2019
# 404   Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2016
# 405   Reynaldo Gonçalves (CEG: CGH.PH.SP.027102-0.01)  ...           2017
#
#      Data do Incio da Semana Din Instante GE Comp 3         Din Instante  \
# 401                                             NaN  31/12/2015 00:00:00
# 402                                             NaN  31/12/2018 00:00:00
# 403                                             NaN  31/12/2019 00:00:00
# 404                                             NaN  31/12/2016 00:00:00
# 405                                             NaN  31/12/2017 00:00:00
#
#      Din Instante GE Comp 3 Período Data 1 GE Comp 3  Período Exibido GE  \
# 401     01/01/2015 00:00:00      01/01/2015 00:00:00                   1
# 402     01/01/2018 00:00:00      01/01/2018 00:00:00                   1
# 403     01/01/2019 00:00:00      01/01/2019 00:00:00                   1
# 404     01/01/2016 00:00:00      01/01/2016 00:00:00                   1
# 405     01/01/2017 00:00:00      01/01/2017 00:00:00                   1
#
#               Table Name  Texto Incio Semana Val Geraenergiacongwh  \
# 401  gr_anusinaprevcarga                 NaN                     0
# 402  gr_anusinaprevcarga                 NaN                     0
# 403  gr_anusinaprevcarga                 NaN                     0
# 404  gr_anusinaprevcarga                 NaN                     0
# 405  gr_anusinaprevcarga                 NaN                     0
#
#     Val Geraenergiaconmwmed
# 401                       0
# 402                       0
# 403                       0
# 404                       0
# 405                       0
#
# [5 rows x 31 columns]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(sp['nom_tipousinasite'], sp['Din Instante'],'o')
plt.show()

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2393 entries, 401 to 18760
# Data columns (total 31 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Data Escala de Tempo 1 GE Comp 3                      2393 non-null   object
#  1   Selecione Comparar GE Comp 3                          2393 non-null   object
#  2   dsc_estado                                            2393 non-null   object
#  3   id_subsistema                                         2393 non-null   object
#  4   Modalidade de Operação                                2393 non-null   object
#  5   nom_tipocombustivel2                                  2393 non-null   object
#  6   nom_tipousinasite                                     2393 non-null   object
#  7   nom_usina2                                            2393 non-null   object
#  8   Período Verifica GE Comp 3                            2393 non-null   object
#  9   USINACEG                                              2393 non-null   object
#  10  Selecione Tipo de GE Comp 3                           2393 non-null   object
#  11  cod_aneel (tb_referenciacegusina (Conjunto))          0 non-null      float64
#  12  cod_aneel (tb_referenciacegusina1 (PrevCarga))        2342 non-null   object
#  13  cod_aneel (tb_usina (Usina))                          0 non-null      float64
#  14  cod_modalidadeoperusiconj (tb usina)                  2150 non-null   object
#  15  cod_nucleoaneel (tb_referenciacegusina (Conjunto))    0 non-null      float64
#  16  cod_nucleoaneel (tb_referenciacegusina (Pequena))     0 non-null      float64
#  17  cod_nucleoaneel (tb_referenciacegusina (Usina))       0 non-null      float64
#  18  cod_nucleoaneel (tb_referenciacegusina1 (PrevCarga))  2393 non-null   object
#  19  Codigo Aneel                                          2342 non-null   object
#  20  Codigo Nucleo Aneel                                   2393 non-null   object
#  21  Data Dica Comp                                        2393 non-null   int64
#  22  Data do Incio da Semana Din Instante GE Comp 3        0 non-null      float64
#  23  Din Instante                                          2393 non-null   object
#  24  Din Instante GE Comp 3                                2393 non-null   object
#  25  Período Data 1 GE Comp 3                              2393 non-null   object
#  26  Período Exibido GE                                    2393 non-null   int64
#  27  Table Name                                            2393 non-null   object
#  28  Texto Incio Semana                                    0 non-null      float64
#  29  Val Geraenergiacongwh                                 2393 non-null   object
#  30  Val Geraenergiaconmwmed                               2393 non-null   object
# dtypes: float64(7), int64(2), object(22)
# memory usage: 678.2+ KB

# %%
import datetime

date_time = sp['Din Instante']
date_time = datetime.datetime.strptime(date_time, '%Y/%m/%d %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-866e846c4041> in <module>
#       2
#       3 date_time = sp['Din Instante']
# ----> 4 date_time = datetime.datetime.strptime(date_time, '%Y/%m/%d %H:%M:%S')
#       5
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
Hidra = sp['nom_tipousinasite'] == 'Hidrelétrica'
Termica = sp['nom_tipousinasite'] == 'Térmica'
Solar = sp['nom_tipousinasite'] == 'Solar'

plt.plot(Hidra['Din Instante'], Hidra['Val Geraenergiacongwh'])
plt.plot(Termica['Din Instante'], Termica['Val Geraenergiacongwh'])
plt.plot(Solar['Din Instante'], Solar['Val Geraenergiacongwh'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Din Instante'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-905556537367> in <module>
#       3 Solar = sp['nom_tipousinasite'] == 'Solar'
#       4
# ----> 5 plt.plot(Hidra['Din Instante'], Hidra['Val Geraenergiacongwh'])
#       6 plt.plot(Termica['Din Instante'], Termica['Val Geraenergiacongwh'])
#       7 plt.plot(Solar['Din Instante'], Solar['Val Geraenergiacongwh'])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Din Instante'

# %%
# df_sample.groupby('Gender')

estado = df.groupby('nom_usina2')

# %%
estado.head()
# Out:
#       Data Escala de Tempo 1 GE Comp 3 Selecione Comparar GE Comp 3  \
# 0                  01/01/2015 00:00:00                      Térmica
# 1                  01/01/2018 00:00:00                      Térmica
# 2                  01/01/2016 00:00:00                      Térmica
# 3                  01/01/2017 00:00:00                      Térmica
# 4                  01/01/2019 00:00:00                      Térmica
# ...                                ...                          ...
# 18758              01/01/2017 00:00:00                      Térmica
# 18761              01/01/2018 00:00:00                      Térmica
# 18762              01/01/2019 00:00:00                      Térmica
# 18763              01/01/2016 00:00:00                      Térmica
# 18764              01/01/2017 00:00:00                      Térmica
#
#         dsc_estado         id_subsistema Modalidade de Operação  \
# 0         AMAZONAS                 Norte               Tipo III
# 1         AMAZONAS                 Norte               Tipo III
# 2         AMAZONAS                 Norte               Tipo III
# 3         AMAZONAS                 Norte               Tipo III
# 4         AMAZONAS                 Norte               Tipo III
# ...            ...                   ...                    ...
# 18758    SAO PAULO  Sudeste/Centro-Oeste               Tipo III
# 18761  MATO GROSSO  Sudeste/Centro-Oeste               Tipo III
# 18762  MATO GROSSO  Sudeste/Centro-Oeste               Tipo III
# 18763  MATO GROSSO  Sudeste/Centro-Oeste               Tipo III
# 18764  MATO GROSSO  Sudeste/Centro-Oeste               Tipo III
#
#       nom_tipocombustivel2 nom_tipousinasite  \
# 0                 Petróleo           Térmica
# 1                 Petróleo           Térmica
# 2                 Petróleo           Térmica
# 3                 Petróleo           Térmica
# 4                 Petróleo           Térmica
# ...                    ...               ...
# 18758             Petróleo           Térmica
# 18761             Petróleo           Térmica
# 18762             Petróleo           Térmica
# 18763             Petróleo           Térmica
# 18764             Petróleo           Térmica
#
#                                    nom_usina2 Período Verifica GE Comp 3  \
# 0                                 Itacoatiara                 Verdadeiro
# 1                                 Itacoatiara                 Verdadeiro
# 2                                 Itacoatiara                 Verdadeiro
# 3                                 Itacoatiara                 Verdadeiro
# 4                                 Itacoatiara                 Verdadeiro
# ...                                       ...                        ...
# 18758   PETROCOQUE S.A. INDUSTRIA E COMERCIO.                 Verdadeiro
# 18761                UTE Emergencial Araguaia                 Verdadeiro
# 18762                UTE Emergencial Araguaia                 Verdadeiro
# 18763                UTE Emergencial Araguaia                 Verdadeiro
# 18764                UTE Emergencial Araguaia                 Verdadeiro
#
#                                                 USINACEG  ... Data Dica Comp  \
# 0               Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2015
# 1               Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2018
# 2               Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2016
# 3               Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2017
# 4               Itacoatiara (CEG: UTE.PE.AM.001157-6.01)  ...           2019
# ...                                                  ...  ...            ...
# 18758   PETROCOQUE S.A. INDUSTRIA E COMERCIO. (CEG: U...  ...           2017
# 18761   UTE Emergencial Araguaia (CEG: UTE.PE.MT.0350...  ...           2018
# 18762   UTE Emergencial Araguaia (CEG: UTE.PE.MT.0350...  ...           2019
# 18763   UTE Emergencial Araguaia (CEG: UTE.PE.MT.0350...  ...           2016
# 18764   UTE Emergencial Araguaia (CEG: UTE.PE.MT.0350...  ...           2017
#
#        Data do Incio da Semana Din Instante GE Comp 3         Din Instante  \
# 0                                                 NaN  31/12/2015 00:00:00
# 1                                                 NaN  31/12/2018 00:00:00
# 2                                                 NaN  31/12/2016 00:00:00
# 3                                                 NaN  31/12/2017 00:00:00
# 4                                                 NaN  31/12/2019 00:00:00
# ...                                               ...                  ...
# 18758                                             NaN  31/12/2017 00:00:00
# 18761                                             NaN  31/12/2018 00:00:00
# 18762                                             NaN  31/12/2019 00:00:00
# 18763                                             NaN  31/12/2016 00:00:00
# 18764                                             NaN  31/12/2017 00:00:00
#
#        Din Instante GE Comp 3 Período Data 1 GE Comp 3  Período Exibido GE  \
# 0         01/01/2015 00:00:00      01/01/2015 00:00:00                   1
# 1         01/01/2018 00:00:00      01/01/2018 00:00:00                   1
# 2         01/01/2016 00:00:00      01/01/2016 00:00:00                   1
# 3         01/01/2017 00:00:00      01/01/2017 00:00:00                   1
# 4         01/01/2019 00:00:00      01/01/2019 00:00:00                   1
# ...                       ...                      ...                 ...
# 18758     01/01/2017 00:00:00      01/01/2017 00:00:00                   1
# 18761     01/01/2018 00:00:00      01/01/2018 00:00:00                   1
# 18762     01/01/2019 00:00:00      01/01/2019 00:00:00                   1
# 18763     01/01/2016 00:00:00      01/01/2016 00:00:00                   1
# 18764     01/01/2017 00:00:00      01/01/2017 00:00:00                   1
#
#                 Table Name  Texto Incio Semana Val Geraenergiacongwh  \
# 0      gr_anusinaprevcarga                 NaN                     0
# 1      gr_anusinaprevcarga                 NaN                     0
# 2      gr_anusinaprevcarga                 NaN            0,29023624
# 3      gr_anusinaprevcarga                 NaN                     0
# 4      gr_anusinaprevcarga                 NaN                     0
# ...                    ...                 ...                   ...
# 18758  gr_anusinaprevcarga                 NaN           51,31376803
# 18761  gr_anusinaprevcarga                 NaN           49,03406482
# 18762  gr_anusinaprevcarga                 NaN                 7e-06
# 18763  gr_anusinaprevcarga                 NaN           80,74301818
# 18764  gr_anusinaprevcarga                 NaN          110,72698234
#
#       Val Geraenergiaconmwmed
# 0                           0
# 1                           0
# 2                    0,033041
# 3                           0
# 4                           0
# ...                       ...
# 18758                5,857736
# 18761                5,597495
# 18762                       0
# 18763                9,192055
# 18764               12,640066
#
# [11636 rows x 31 columns]

# %%
sp['Val Geraenergiacongwh'] = sp['Val Geraenergiacongwh'].astype(float, errors = 'raise')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5ccf690a08ed> in <module>
# ----> 1 sp['Val Geraenergiacongwh'] = sp['Val Geraenergiacongwh'].astype(float, errors = 'raise')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     993     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     994         # Explicit copy, or required since NumPy can't view from / to object.
# --> 995         return arr.astype(dtype, copy=True)
#     996
#     997     return arr.view(dtype)
#
# ValueError: could not convert string to float: '97,22876582'

# %%
float(sp[,].replace(".",",")

# %%
df1['Val Geraenergiacongwh'] == 0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18762    False
# 18763    False
# 18764    False
# 18765    False
# 18766    False
# Name: Val Geraenergiacongwh, Length: 18767, dtype: bool

# %%
# PARAMOS AQUI, GALERA

#list(filter(lambda a: a != 2, x))

# %%
#df.drop(indexNames , inplace=True)

#indexNames = df[ (df['Price'] >= 30)
                & (df['Price'] <= 70) ].index
#df.drop(indexNames , inplace=True)

# %%
# método .info() para obter os tipos de dados todas as variáveis

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18767 entries, 0 to 18766
# Data columns (total 31 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Data Escala de Tempo 1 GE Comp 3                      18767 non-null  object
#  1   Selecione Comparar GE Comp 3                          18767 non-null  object
#  2   dsc_estado                                            18767 non-null  object
#  3   id_subsistema                                         18767 non-null  object
#  4   Modalidade de Operação                                18767 non-null  object
#  5   nom_tipocombustivel2                                  18767 non-null  object
#  6   nom_tipousinasite                                     18767 non-null  object
#  7   nom_usina2                                            18767 non-null  object
#  8   Período Verifica GE Comp 3                            18767 non-null  object
#  9   USINACEG                                              18767 non-null  object
#  10  Selecione Tipo de GE Comp 3                           18767 non-null  object
#  11  cod_aneel (tb_referenciacegusina (Conjunto))          0 non-null      float64
#  12  cod_aneel (tb_referenciacegusina1 (PrevCarga))        18475 non-null  object
#  13  cod_aneel (tb_usina (Usina))                          0 non-null      float64
#  14  cod_modalidadeoperusiconj (tb usina)                  17571 non-null  object
#  15  cod_nucleoaneel (tb_referenciacegusina (Conjunto))    0 non-null      float64
#  16  cod_nucleoaneel (tb_referenciacegusina (Pequena))     0 non-null      float64
#  17  cod_nucleoaneel (tb_referenciacegusina (Usina))       0 non-null      float64
#  18  cod_nucleoaneel (tb_referenciacegusina1 (PrevCarga))  18767 non-null  object
#  19  Codigo Aneel                                          18475 non-null  object
#  20  Codigo Nucleo Aneel                                   18767 non-null  object
#  21  Data Dica Comp                                        18767 non-null  int64
#  22  Data do Incio da Semana Din Instante GE Comp 3        0 non-null      float64
#  23  Din Instante                                          18767 non-null  object
#  24  Din Instante GE Comp 3                                18767 non-null  object
#  25  Período Data 1 GE Comp 3                              18767 non-null  object
#  26  Período Exibido GE                                    18767 non-null  int64
#  27  Table Name                                            18767 non-null  object
#  28  Texto Incio Semana                                    0 non-null      float64
#  29  Val Geraenergiacongwh                                 18767 non-null  object
#  30  Val Geraenergiaconmwmed                               18767 non-null  object
# dtypes: float64(7), int64(2), object(22)
# memory usage: 4.4+ MB

# %%
# método .columns para examinar os nomes de todas as variáveis

df.columns
# Out:
# Index(['Data Escala de Tempo 1 GE Comp 3', 'Selecione Comparar GE Comp 3',
#        'dsc_estado', 'id_subsistema', 'Modalidade de Operação',
#        'nom_tipocombustivel2', 'nom_tipousinasite', 'nom_usina2',
#        'Período Verifica GE Comp 3', 'USINACEG', 'Selecione Tipo de GE Comp 3',
#        'cod_aneel (tb_referenciacegusina (Conjunto))',
#        'cod_aneel (tb_referenciacegusina1 (PrevCarga))',
#        'cod_aneel (tb_usina (Usina))', 'cod_modalidadeoperusiconj (tb usina)',
#        'cod_nucleoaneel (tb_referenciacegusina (Conjunto))',
#        'cod_nucleoaneel (tb_referenciacegusina (Pequena))',
#        'cod_nucleoaneel (tb_referenciacegusina (Usina))',
#        'cod_nucleoaneel (tb_referenciacegusina1 (PrevCarga))', 'Codigo Aneel',
#        'Codigo Nucleo Aneel', 'Data Dica Comp',
#        'Data do Incio da Semana Din Instante GE Comp 3', 'Din Instante',
#        'Din Instante GE Comp 3', 'Período Data 1 GE Comp 3',
#        'Período Exibido GE', 'Table Name', 'Texto Incio Semana',
#        'Val Geraenergiacongwh', 'Val Geraenergiaconmwmed'],
#       dtype='object')

# %%
# descobrindo o números de linhas do dataset

df.shape
# Out:
# (18767, 31)

# %%
# verificando valores nulos/NaN

df.isnull().sum()
# Out:
# Data Escala de Tempo 1 GE Comp 3                            0
# Selecione Comparar GE Comp 3                                0
# dsc_estado                                                  0
# id_subsistema                                               0
# Modalidade de Operação                                      0
# nom_tipocombustivel2                                        0
# nom_tipousinasite                                           0
# nom_usina2                                                  0
# Período Verifica GE Comp 3                                  0
# USINACEG                                                    0
# Selecione Tipo de GE Comp 3                                 0
# cod_aneel (tb_referenciacegusina (Conjunto))            18767
# cod_aneel (tb_referenciacegusina1 (PrevCarga))            292
# cod_aneel (tb_usina (Usina))                            18767
# cod_modalidadeoperusiconj (tb usina)                     1196
# cod_nucleoaneel (tb_referenciacegusina (Conjunto))      18767
# cod_nucleoaneel (tb_referenciacegusina (Pequena))       18767
# cod_nucleoaneel (tb_referenciacegusina (Usina))         18767
# cod_nucleoaneel (tb_referenciacegusina1 (PrevCarga))        0
# Codigo Aneel                                              292
# Codigo Nucleo Aneel                                         0
# Data Dica Comp                                              0
# Data do Incio da Semana Din Instante GE Comp 3          18767
# Din Instante                                                0
# Din Instante GE Comp 3                                      0
# Período Data 1 GE Comp 3                                    0
# Período Exibido GE                                          0
# Table Name                                                  0
# Texto Incio Semana                                      18767
# Val Geraenergiacongwh                                       0
# Val Geraenergiaconmwmed                                     0
# dtype: int64

# %% [markdown]
# As variáveis **Data do Incio da Semana Din Instante GE Comp 3** e **Texto Incio Semana** têm 'NaN' em todas as observações

# %%
# A função .nunique() retorna o número de elementos únicos na variável.

df['Selecione Comparar GE Comp 3'].nunique()
# Out:
# 5

# %%
# Quais são essas variáveis

matriz = df['Selecione Comparar GE Comp 3'].value_counts()
matriz.head()
# Out:
# Hidrelétrica    9027
# Térmica         4664
# Eólica          4396
# Solar            635
# Nuclear           45
# Name: Selecione Comparar GE Comp 3, dtype: int64

# %%
df['Selecione Comparar GE Comp 3.1'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Selecione Comparar GE Comp 3.1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-443f41dc4f2a> in <module>
# ----> 1 df['Selecione Comparar GE Comp 3.1'].nunique()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Selecione Comparar GE Comp 3.1'

# %%
# Quais são essas variáveis

matriz1 = df['Selecione Comparar GE Comp 3.1'].value_counts()
matriz1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Selecione Comparar GE Comp 3.1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-47f22714c220> in <module>
#       1 # Quais são essas variáveis
#       2
# ----> 3 matriz1 = df['Selecione Comparar GE Comp 3.1'].value_counts()
#       4 matriz1.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Selecione Comparar GE Comp 3.1'

# %%
df['Data Dica Comp'].nunique()
# Out:
# 23

# %%
ano = df['Data Dica Comp'].value_counts()
ano.head(23)
# Out:
# 2021    5
# 2020    5
# 2019    5
# 2018    5
# 2017    5
# 2016    5
# 2015    5
# 2006    4
# 2007    4
# 2008    4
# 2009    4
# 2010    4
# 2011    4
# 2012    4
# 2013    4
# 2014    4
# 2005    3
# 2004    3
# 2003    3
# 2002    3
# 2001    3
# 2000    3
# 1999    3
# Name: Data Dica Comp, dtype: int64

# %%
# checando se ano comtempla todas as observações

print(ano.sum())
# Out:
# 92

# %%
# criando máscara booleana para condições iguais a 'Hidrelétrica'

#hidreletrica = id_counts == 2

df_hidreletrica = df[df['Selecione Comparar GE Comp 3'] == 'Hidrelétrica']

# %%
df_hidreletrica.head()
# Out:
#    Data Escala de Tempo 1 GE Comp 3 Selecione Comparar GE Comp 3 Codigo Aneel  \
# 53              01/01/1999 00:00:00                 Hidrelétrica            *
# 54              01/01/2000 00:00:00                 Hidrelétrica            *
# 55              01/01/2001 00:00:00                 Hidrelétrica            *
# 56              01/01/2002 00:00:00                 Hidrelétrica            *
# 57              01/01/2003 00:00:00                 Hidrelétrica            *
#
#    Codigo Nucleo Aneel  Data Dica Comp  \
# 53                   *            1999
# 54                   *            2000
# 55                   *            2001
# 56                   *            2002
# 57                   *            2003
#
#     Data do Incio da Semana Din Instante GE Comp 3  \
# 53                                             NaN
# 54                                             NaN
# 55                                             NaN
# 56                                             NaN
# 57                                             NaN
#
#    Data Escala de Tempo 1 GE Comp 3.1  Período Exibido GE  \
# 53                01/01/1999 00:00:00                   1
# 54                01/01/2000 00:00:00                   1
# 55                01/01/2001 00:00:00                   1
# 56                01/01/2002 00:00:00                   1
# 57                01/01/2003 00:00:00                   1
#
#    Selecione Comparar GE Comp 3.1  Texto Incio Semana  \
# 53                   Hidrelétrica                 NaN
# 54                   Hidrelétrica                 NaN
# 55                   Hidrelétrica                 NaN
# 56                   Hidrelétrica                 NaN
# 57                   Hidrelétrica                 NaN
#
#    Selecione Tipo de GE Comp 3
# 53             325373,24058916
# 54             335971,01454259
# 55              292920,7990786
# 56             316015,11152007
# 57             337295,07049707

# %%
print (df[pd.to_numeric(df['Selecione Tipo de GE Comp 3'], errors='coerce').isnull()])
# Out:
#    Data Escala de Tempo 1 GE Comp 3 Selecione Comparar GE Comp 3 Codigo Aneel  \
# 0               01/01/1999 00:00:00                      Térmica            *
# 1               01/01/2000 00:00:00                      Térmica            *
# 2               01/01/2001 00:00:00                      Térmica            *
# 3               01/01/2002 00:00:00                      Térmica            *
# 4               01/01/2003 00:00:00                      Térmica            *
# ..                              ...                          ...          ...
# 87              01/01/2017 00:00:00                       Eólica            *
# 88              01/01/2018 00:00:00                       Eólica            *
# 89              01/01/2019 00:00:00                       Eólica            *
# 90              01/01/2020 00:00:00                       Eólica            *
# 91              01/01/2021 00:00:00                       Eólica            *
#
#    Codigo Nucleo Aneel  Data Dica Comp  \
# 0                    *            1999
# 1                    *            2000
# 2                    *            2001
# 3                    *            2002
# 4                    *            2003
# ..                 ...             ...
# 87                   *            2017
# 88                   *            2018
# 89                   *            2019
# 90                   *            2020
# 91                   *            2021
#
#     Data do Incio da Semana Din Instante GE Comp 3  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 87                                             NaN
# 88                                             NaN
# 89                                             NaN
# 90                                             NaN
# 91                                             NaN
#
#    Data Escala de Tempo 1 GE Comp 3.1  Período Exibido GE  \
# 0                 01/01/1999 00:00:00                   1
# 1                 01/01/2000 00:00:00                   1
# 2                 01/01/2001 00:00:00                   1
# 3                 01/01/2002 00:00:00                   1
# 4                 01/01/2003 00:00:00                   1
# ..                                ...                 ...
# 87                01/01/2017 00:00:00                   1
# 88                01/01/2018 00:00:00                   1
# 89                01/01/2019 00:00:00                   1
# 90                01/01/2020 00:00:00                   1
# 91                01/01/2021 00:00:00                   1
#
#    Selecione Comparar GE Comp 3.1  Texto Incio Semana  \
# 0                         Térmica                 NaN
# 1                         Térmica                 NaN
# 2                         Térmica                 NaN
# 3                         Térmica                 NaN
# 4                         Térmica                 NaN
# ..                            ...                 ...
# 87                         Eólica                 NaN
# 88                         Eólica                 NaN
# 89                         Eólica                 NaN
# 90                         Eólica                 NaN
# 91                         Eólica                 NaN
#
#    Selecione Tipo de GE Comp 3
# 0                12329,5680043
# 1               15220,91427329
# 2               19689,21694907
# 3               17504,28799394
# 4               15337,32004255
# ..                         ...
# 87              42336,45005842
# 88              48442,86048863
# 89             55931,655957650
# 90              56994,10305024
# 91              29202,78957679
#
# [92 rows x 11 columns]

# %%
# convertendo as variaveis numéricas para números

numeric_cols = df.columns.drop(['Data Escala de Tempo 1 GE Comp 3',
                                'Selecione Comparar GE Comp 3',
                                'Codigo Aneel',
                                'Codigo Nucleo Aneel', 
                                'Data Dica Comp', 
                                'Data do Incio da Semana Din Instante GE Comp 3', 
                                'Data Escala de Tempo 1 GE Comp 3.1',
                                'Período Exibido GE', 
                                'Selecione Comparar GE Comp 3.1', 
                                'Texto Incio Semana'])


df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "12329,5680043"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-99b2df7c46ca> in <module>
#      13
#      14
# ---> 15 df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "12329,5680043" at position 0

# %%
# esta variável está como string (precisa converter)

df_hidreletrica['Selecione Tipo de GE Comp 3'].sum()
# Out:
# '325373,24058916335971,01454259292920,7990786316015,11152007337295,07049707352536,28550275370852,42818839382746,16382933406496,98107412398304,0810519415138,96906271423132,5233117449615,35134249439533,07056302412710,03645974391376,225303390272,007402221416766,70658928401148,05901522417934,30118297418182,25090291415503,0415294210475,97899475'
